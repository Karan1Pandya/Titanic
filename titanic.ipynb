# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\Karan\\Documents\\Py-pandas\\Titanic\\titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                                 Name   Sex         Age  \
# count                                            891   891  714.000000
# unique                                           891     2         NaN
# top     Andersson, Mr. August Edvard ("Wennerstrom")  male         NaN
# freq                                               1   577         NaN
# mean                                             NaN   NaN   29.699118
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.iloc[20:31,:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
#
#                                                  Name     Sex
# 20                               Fynney, Mr. Joseph J    male
# 21                              Beesley, Mr. Lawrence    male
# 22                        McGowan, Miss. Anna "Annie"  female
# 23                       Sloper, Mr. William Thompson    male
# 24                      Palsson, Miss. Torborg Danira  female
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female
# 26                            Emir, Mr. Farred Chehab    male
# ...

# %%
data.iloc[20:31,4:8]
# Out:
#        Sex   Age  SibSp  Parch
# 20    male  35.0      0      0
# 21    male  34.0      0      0
# 22  female  15.0      0      0
# 23    male  28.0      0      0
# 24  female   8.0      3      1
# 25  female  38.0      1      5
# 26    male   NaN      0      0
# 27    male  19.0      3      2
# 28  female   NaN      0      0
# 29    male   NaN      0      0
# 30    male  40.0      0      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# data with numeric column
# data with non numeric column

# %%
data_col=data.columns
print(data_col)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# df_numerics_only =data.select_dtypes(include=np.number)
# df_numerics_only

# %%
data['Fare'].dtype
# Out:
# dtype('float64')

# %%
d=[]
for c in data_col:
       if data[c].dtype=='int64':
            d.append(c)
            
print(d)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch']

# %%
abcde=[c for c in data.columns if data[c].dtype=="int64" or data[c].dtype==object or data[c].dtype==float]
print(abcde)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
data_tuple=[(d,data[d].dtype) for d in abcde]
print(data_tuple)
# Out:
# [('PassengerId', dtype('int64')), ('Survived', dtype('int64')), ('Pclass', dtype('int64')), ('Name', dtype('O')), ('Sex', dtype('O')), ('Age', dtype('float64')), ('SibSp', dtype('int64')), ('Parch', dtype('int64')), ('Ticket', dtype('O')), ('Fare', dtype('float64')), ('Cabin', dtype('O')), ('Embarked', dtype('O'))]

# %%
s=[i[0] for i in data_tuple if i[1]=='int64' or i[1]==float]
print(s)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
t=[i[0] for i in data_tuple if i[1]==object]
print(t)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
data.select_dtypes(include='object')
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
data.select_dtypes(exclude='object')
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0              1         0       3  22.0      1      0    7.2500
# 1              2         1       1  38.0      1      0   71.2833
# 2              3         1       3  26.0      0      0    7.9250
# 3              4         1       1  35.0      1      0   53.1000
# 4              5         0       3  35.0      0      0    8.0500
# 5              6         0       3   NaN      0      0    8.4583
# 6              7         0       1  54.0      0      0   51.8625
# 7              8         0       3   2.0      3      1   21.0750
# 8              9         1       3  27.0      0      2   11.1333
# 9             10         1       2  14.0      1      0   30.0708
# 10            11         1       3   4.0      1      1   16.7000
# 11            12         1       1  58.0      0      0   26.5500
# 12            13         0       3  20.0      0      0    8.0500
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                                 Name   Sex         Age  \
# count                                            891   891  714.000000
# unique                                           891     2         NaN
# top     Andersson, Mr. August Edvard ("Wennerstrom")  male         NaN
# freq                                               1   577         NaN
# mean                                             NaN   NaN   29.699118
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
np.nanpercentile(data['Age'],75,)
# Out:
# 38.0

# %%
min(data['Age'])
# Out:
# 0.42

# %%
def iqr_outliers(num_array):
    """
    Finds outliers based on IQR method
    Params:
    -------
    num_arrar: numpy array or list
    Returns:
    --------
    List of outliers if present
    """
    # Find 25th percentile / q1
    q1 = np.nanpercentile(num_array, 25)
    # Find 25th percentile / q1
    q3 = np.nanpercentile(num_array, 75)
    # Find IQR
    iqr = q3 - q1
    # Define upper and lower limits for outlier detection
    upper_limit = q3 + (1.5 * iqr)
    lower_limit = q1 - (1.5 * iqr)
    return [num for num in num_array if num > upper_limit or num < lower_limit]




def basic_explo(df):
#     df.shape
    print('rows:{},column:{}'.format((str(df.shape[0])),str(df.shape[1])))
    print(df.info())
    print("Descriptive stats for numeric columns")
    print(df.describe)
    print("Descreptive stats for catogrial columns")
    print(df.describe(include='object'))
    null_df=pd.DataFrame(df.isnull().sum())
    null_df.columns=['count']
    print(null_df[null_df['count']>0])
    df_num=df.select_dtypes(exclude='object')
    print(df_num)
    df_num_cols=df_num.columns
    for c in df_num_cols:
        print(c)
        print(iqr_outliers(df_num[c]))

# %%
basic_explo(data)
# Out:
# rows:891,column:12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None
# Descriptive stats for numeric columns
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ...

# %%
(data['Sex'].value_counts()/data['Sex'].value_counts().sum())*100
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
print(len(data[data['Survived']==0]))
print(len(data[data['Survived']==1]))
# Out:
# 549
# 342

# %%
(data['Survived'].value_counts()/data['Survived'].value_counts().sum())*100
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
(data['Pclass'].value_counts())
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
data.groupby(['Sex'])['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
data.groupby(['Pclass'])['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
data.groupby(['Sex','Survived'])['Age'].min()
# Out:
# Sex     Survived
# female  0           2.00
#         1           0.75
# male    0           1.00
#         1           0.42
# Name: Age, dtype: float64

# %%
data.groupby(['Sex','Survived'])['Age'].agg(['mean','max','min','median'])
# Out:
#                       mean   max   min  median
# Sex    Survived
# female 0         25.046875  57.0  2.00    24.5
#        1         28.847716  63.0  0.75    28.0
# male   0         31.618056  74.0  1.00    29.0
#        1         27.276022  80.0  0.42    28.0

# %%
data['Age'].map(lambda x: 'Senior 'if  x>60  else  'Regular')
# Out:
# 0      Regular
# 1      Regular
# 2      Regular
# 3      Regular
# 4      Regular
# 5      Regular
# 6      Regular
# 7      Regular
# 8      Regular
# 9      Regular
# 10     Regular
# 11     Regular
# 12     Regular
# 13     Regular
# 14     Regular
# 15     Regular
# 16     Regular
# 17     Regular
# 18     Regular
# 19     Regular
# 20     Regular
# 21     Regular
# 22     Regular
# 23     Regular
# 24     Regular
# 25     Regular
# 26     Regular
# 27     Regular
# 28     Regular
# 29     Regular
#         ...
# 861    Regular
# 862    Regular
# 863    Regular
# 864    Regular
# 865    Regular
# 866    Regular
# 867    Regular
# 868    Regular
# 869    Regular
# 870    Regular
# 871    Regular
# 872    Regular
# 873    Regular
# 874    Regular
# 875    Regular
# 876    Regular
# 877    Regular
# 878    Regular
# 879    Regular
# 880    Regular
# 881    Regular
# 882    Regular
# 883    Regular
# 884    Regular
# 885    Regular
# 886    Regular
# 887    Regular
# 888    Regular
# ...

# %%
data['total_members']=data.apply(lambda x:x['SibSp']+x['Parch'], axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
def age_group(Age):
    if Age<2:
        return 'infant'
    elif Age<18:
        return 'kid'
    elif Age<60:
        return 'Adult'
    else:
        return 'Senior'

# %%
data['age_group']=data['Age'].map(age_group)
data['age_group']
# Out:
# 0       Adult
# 1       Adult
# 2       Adult
# 3       Adult
# 4       Adult
# 5      Senior
# 6       Adult
# 7         kid
# 8       Adult
# 9         kid
# 10        kid
# 11      Adult
# 12      Adult
# 13      Adult
# 14        kid
# 15      Adult
# 16        kid
# 17     Senior
# 18      Adult
# 19     Senior
# 20      Adult
# 21      Adult
# 22        kid
# 23      Adult
# 24        kid
# 25      Adult
# 26     Senior
# 27      Adult
# 28     Senior
# 29     Senior
#         ...
# 861     Adult
# 862     Adult
# 863    Senior
# 864     Adult
# 865     Adult
# 866     Adult
# 867     Adult
# 868    Senior
# 869       kid
# 870     Adult
# 871     Adult
# 872     Adult
# 873     Adult
# 874     Adult
# 875       kid
# 876     Adult
# 877     Adult
# 878    Senior
# 879     Adult
# 880     Adult
# 881     Adult
# 882     Adult
# 883     Adult
# 884     Adult
# 885     Adult
# 886     Adult
# 887     Adult
# 888    Senior
# 889     Adult
# 890     Adult
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  total_members age_group
# 0      0         A/5 21171   7.2500   NaN        S              1     Adult
# 1      0          PC 17599  71.2833   C85        C              1     Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S              0     Adult
# ...

# %%
(data.groupby(['age_group','Survived'])['Survived'].count()/data.groupby(['age_group'])['Survived'].count()*100)
# Out:
# age_group  Survived
# Adult      0           61.391304
#            1           38.608696
# Senior     0           70.935961
#            1           29.064039
# infant     0           14.285714
#            1           85.714286
# kid        0           50.505051
#            1           49.494949
# Name: Survived, dtype: float64

# %%
(data.groupby(['Sex','age_group','Survived'])['Survived'].count())
# Out:
# Sex     age_group  Survived
# female  Adult      0            47
#                    1           155
#         Senior     0            17
#                    1            40
#         infant     1             4
#         kid        0            17
#                    1            34
# male    Adult      0           306
#                    1            67
#         Senior     0           127
#                    1            19
#         infant     0             2
#                    1             8
#         kid        0            33
#                    1            15
# Name: Survived, dtype: int64

# %%
data.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
data.pivot_table(index='Sex',values='Age',aggfunc='mean')
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
data.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
data.pivot_table(index='Sex',columns='Survived',values='Age',aggfunc='median')
# Out:
# Survived     0     1
# Sex
# female    24.5  28.0
# male      29.0  28.0

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data.pivot_table(index=['Sex','Survived'],values='Age',aggfunc='mean').reset_index()
# Out:
#       Sex  Survived        Age
# 0  female         0  25.046875
# 1  female         1  28.847716
# 2    male         0  31.618056
# 3    male         1  27.276022

# %%
new_df=data.pivot_table(index=['Sex','Survived'],values='Age',aggfunc='mean')
new_df
# Out:
#                        Age
# Sex    Survived
# female 0         25.046875
#        1         28.847716
# male   0         31.618056
#        1         27.276022

# %%
dated=data.merge(new_df,on=['Sex','Survived'],how='inner')
dated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              5         0       3
# 2              6         0       3
# 3              7         0       1
# 4              8         0       3
# 5             13         0       3
# 6             14         0       3
# 7             17         0       3
# 8             21         0       2
# 9             27         0       3
# 10            28         0       1
# 11            30         0       3
# 12            31         0       1
# 13            34         0       2
# 14            35         0       1
# 15            36         0       1
# 16            38         0       3
# 17            43         0       3
# 18            46         0       3
# 19            47         0       3
# 20            49         0       3
# 21            51         0       3
# 22            52         0       3
# 23            55         0       1
# 24            58         0       3
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  total_members age_group
# 0      0         A/5 21171   7.2500   NaN        S              1     Adult
# 1      0          PC 17599  71.2833   C85        C              1     Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S              0     Adult
# ...

# %%
data.rename(columns={'Age_y':'AvgAge'},inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
fig=plt.figure(figsize=(5,7))

# %%
pass_count=data.pivot_table(index='Sex',values='Survived',aggfunc='count').reset_index()
pass_count
# Out:
#       Sex  Survived
# 0  female       314
# 1    male       577

# %%
ax=plt.bar(pass_count.index,pass_count['Survived'])
plt.show()

# %%
data['Sex'].value_counts().plot(kind='bar')
plt.xlabel('Passenger Gender')
plt.ylabel('Count of Passenger')
plt.title('Passenger by Sex')
plt.show()

# %%
ax=plt.bar(pass_count.index,pass_count['Survived'],color='black')
plt.xlabel('Passenger Gender')
plt.ylabel('Count of Passenger')
plt.title('Passenger by Sex',fontsize=16,color='green')
plt.ylim(ymax=700)
for num,count in enumerate(pass_count['Survived']):
    plt.text(x=num,y=count-200,s=str(count),fontsize=15 ,color='white')
plt.show()

# %%
l1=[1,2,3]
l2=['a','b','c']
l3=range(0,len(l2))
for a,b in zip(l1,l2):
    print(a,b)

print('===========')
for a,b in zip(l3,l2):
    print(a,b)
# Out:
# 1 a
# 2 b
# 3 c
# ...
# 0 a
# 1 b
# 2 c

# %%
for num,val in enumerate (['a','b','c','d']):
    print(num,val)
# Out:
# 0 a
# 1 b
# 2 c
# 3 d

# %%
for num,count in enumerate(pass_count['Survived']):
    print(num,count)
# Out:
# 0 314
# 1 577

# %%
bx=plt.pie(data['Survived'].value_counts(),autopct='%.2f',labels=['Dead','Survive'])

# %%
cx=plt.boxplot(data['Fare'],showfliers=False)

# %%
dx=data.boxplot(column='Fare',by='Survived',showfliers=False)

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
